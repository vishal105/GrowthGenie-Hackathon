# %%
import pandas as pd

# %%
from CustomerAnalysis import CustomerAnalysis

# %%
customer = CustomerAnalysis(1001)
# Out:
# Connected to the database.
# h:\hackathon\growthgenie\hack-code\utilities\AzureSqlLoader.py:47: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, self.conn)
# Table 'Accounts' loaded into DataFrame.
# h:\hackathon\growthgenie\hack-code\utilities\AzureSqlLoader.py:47: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, self.conn)
# Table 'Customers' loaded into DataFrame.
# ...

# %%
customer.account_data
# Out:
#             ACCOUNTID  CUSTOMERID      ACCOUNTTYPE  ACCOUNTBALANCE  \
# 0  HMGR29940616830431        1001  Savings account       1136595.0
# 1  UVZJ11140960808979        1001  Savings account       2222612.0
#
#   ACCOUNTSTATUS  INTERESTRATE OPENINGDATE LASTTRANSACTIONDATE
# 0        Closed          5.95  2020-12-05          2022-09-23
# 1        Closed          9.24  2012-08-31          2023-04-15

# %%
customer.investment_data
# Out:
#   INVESTMENTACCOUNTID  CUSTOMERID     ACCOUNTTYPE INVESTMENTAMOUNT  \
# 0  CSBD28970375408960        1001          Stocks             None
# 1  DDWL33836319153290        1001          Stocks             None
# 2  RHYC07550614298355        1001    Mutual Funds             None
# 3  YCLP07660805086462        1001  Fixed Deposits             None
#
#   INVESTMENTSTATUS INVESTMENTSTARTDATE INVESTMENTENDDATE  RETURNS  \
# 0           Closed          2021-05-14        2022-04-07    14.69
# 1           Active          2018-12-21        2022-03-13    17.66
# 2           Closed          2019-08-01        2023-02-28    10.50
# 3           Active          2019-03-23        2022-10-27    11.60
#
#   INVESTMENTPORTFOLIO
# 0            51174163
# 1            09104822
# 2            02466828
# 3            27218082

# %%
customer.loans_data

# %%
customer.fd_data
# Out:
#    FIXEDDEPOSITID INVESTMENTACCOUNTID  PRINCIPALAMOUNT  INTERESTRATE  \
# 0            1516  RHYC07550614298355         917672.0          8.37
# 1            1911  DDWL33836319153290         358361.0          5.20
# 2            1922  DDWL33836319153290         169335.0          6.22
# 3            2458  YCLP07660805086462         766501.0          8.17
# 4            3375  RHYC07550614298355         234322.0          8.69
# 5            3476  CSBD28970375408960         879267.0          8.67
#
#   MATURITYDATE INTERESTPAYMENTFREQUENCY  MATURITYAMOUNT  CUSTOMERID
# 0   2020-10-01                  Monthly       4905415.0        1001
# 1   2018-11-05                    Daily       1533828.0        1001
# 2   2022-01-31                Quarterly       1136629.0        1001
# 3   2018-11-02                    Daily       6293251.0        1001
# 4   2018-11-01                   Weekly       6558503.0        1001
# 5   2018-10-22                   Yearly       5802172.0        1001

# %%
customer.stocks_data
# Out:
#    STOCKID  STOCKSYMBOL                                STOCKNAME  \
# 0     1045   ASIANPAINT                     Asian Paints Limited
# 1     1366         INFY                          Infosys Limited
# 2     1499        TITAN                    Titan Company Limited
# 3     2292        WIPRO                            Wipro Limited
# 4     3161    EICHERMOT                    Eicher Motors Limited
# 5     3307   TATAMOTORS                      Tata Motors Limited
# 6     3699    POWERGRID  Power Grid Corporation of India Limited
#
#   STOCKEXCHANGE  PURCHASEPRICE PURCHASEDATE  QUANTITY INVESTMENTACCOUNTID  \
# 0           BSE          389.0   2022-05-20        42  DDWL33836319153290
# 1           NSE          894.0   2023-04-23        89  RHYC07550614298355
# 2           BSE          475.0   2020-01-29        30  DDWL33836319153290
# 3           NSE          569.0   2018-12-12        71  DDWL33836319153290
# 4           NSE          796.0   2021-06-04        19  DDWL33836319153290
# ...

# %%
customer.transactions_data
# Out:
#    TRANSACTIONID           ACCOUNTID   TRANSACTIONTYPE   AMOUNT  \
# 0          10112  HMGR29940616830431        Withdrawal  24598.0
# 1          12000  UVZJ11140960808979  Cash Withdrawals   2318.0
# 2          12321  HMGR29940616830431        Withdrawal  17674.0
# 3          14112  UVZJ11140960808979  Cash Withdrawals   7539.0
# 4          14454  UVZJ11140960808979        Withdrawal  48534.0
#
#   TRANSACTIONDATE TRANSACTIONSTATUS  CUSTOMERID
# 0      2022-11-29           Pending        1001
# 1      2022-09-26           Pending        1001
# 2      2022-06-21         Completed        1001
# 3      2022-06-14           Pending        1001
# 4      2023-02-13            Failed        1001

# %%
customer.customer_data
# Out:
#    CUSTOMERID FIRSTNAME LASTNAME DATEOFBIRTH GENDER  \
# 0        1001      John  Vasquez  1970-03-18      M
#
#                                              ADDRESS         PHONE  \
# 0  668 Taylor Forges Suite 808 Martinezville, ME ...  627.428.6446
#
#                EMAIL          UID
# 0  emorris@gmail.com  460-21-7303

# %%
customer.mf_data
# Out:
#    MUTUALFUNDID                      FUNDNAME        FUNDMANAGER  \
# 0          1212      Nippon India Mutual Fund        Samir Rachh
# 1          1330  ICICI Prudential Mutual Fund     Sankaran Naren
# 2          1778    Kotak Mahindra Mutual Fund   Harsha Upadhyaya
# 3          2543    Kotak Mahindra Mutual Fund   Harsha Upadhyaya
# 4          2794               SBI Mutual Fund      R. Srinivasan
# 5          3537              Axis Mutual Fund  Shreyash Devalkar
# 6          3552              Axis Mutual Fund  Shreyash Devalkar
# 7          3582             PPFAS Mutual Fund     Rajeev Thakkar
# 8          3662       Mirae Asset Mutual Fund     Neelesh Surana
#
#        FUNDTYPE     NAV  INVESTMENTAMOUNT INVESTMENTDATE INVESTMENTACCOUNTID  \
# 0  Money Market   74.21        87395764.0     2011-12-04  DDWL33836319153290
# 1  Money Market  151.74        96766157.0     2008-11-28  CSBD28970375408960
# 2        Hybrid  187.66        40177939.0     2022-03-16  DDWL33836319153290
# ...
